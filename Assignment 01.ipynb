# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here
print("Name:\tSimra\nFather Name:\tZafar Ali\nDate of birth:\t17-10-2005")
# Out:
# Name:	Simra
# Father Name:	Zafar Ali
# Date of birth:	17-10-2005

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here
name = "Simra"
age = 20
city = "Karachi"
interest = "Learning Python"

print(f"My name is {name}")
print(f"I am {age} year old")
print(f"I live in {city}")
print(f"My interest is {interest}")
# Out:
# My name is Simra
# I am 20 year old
# I live in Karachi
# My interest is Learning Python

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here
a = 10
b = 5

#Arithmetic Operators
print(a + b)  #Addition
print(a - b)  #Subtraction
print(a * b)  #Multiplication
print(a / b)  #Division
print(a ** 2)  #Exponenciation or Power
print(a % b)  #Modulus
print(a // b)  #Floor Division

#Comparison Operators
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)

#Logical Operators
print(a > b and b < a)
print(a > b or b > a)
print(not(a < b))

#Assignment Operators
a += 5
print(a)

a -= 3
print(a)

#Identity Operators
print(a is b)
print(a is not b)

#Membership Operators
numbers = [1, 2, 3, 4, 5]
print(4 in numbers)
# Out:
# 15
# 5
# 50
# 2.0
# 100
# 0
# 2
# True
# False
# True
# False
# False
# True
# True
# True
# True
# 15
# 12
# False
# True
# True

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here
english = 85
islamiat = 90
math = 80

Total_marks = 300
Obtained_marks = english + islamiat + math 

Percentage = (Obtained_marks / Total_marks) * 100

print(f"English: {english}")
print(f"Islamiat: {islamiat}")
print(f"Math: {math}")
print(f"Total_marks: {Obtained_marks}")
print(f"Percentage: {Percentage}%")
# Out:
# English: 85
# Islamiat: 90
# Math: 80
# Total_marks: 255
# Percentage: 85.0%
